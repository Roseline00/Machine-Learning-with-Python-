# %% [markdown]
# <a href="https://colab.research.google.com/github/Roseline00/Machine-Learning-with-Python-/blob/main/python_refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('it\'s mine')
# Out:
# it's mine

# %%
data=[1,2,3,4,5,6]
print(data[1:6])
# Out:
# [2, 3, 4, 5, 6]

# %% [markdown]
# Variables (ML Anchor)

# %%
#Create and labeled storage basket and put in a number inside
tomato_price=150
papper_price=80

#pull the value out of the basket
print(tomato_price)
print(papper_price)
# Out:
# 150
# 80

# %% [markdown]
# Variables (ML Anchor)

# %%
# THE CLAUS (Features grouped as x)

rainfall_mm=45.2 #clue 1
bags_available=100 #Clue 2
#--- THE GOAL (target labeled as y)
predicted_price=3200 # what our AI calculates

print("Inputs(X):", rainfall_mm,"mm rain,",bags_available,"bags.")
print("Output(y):", predicted_price,"LRD.")
# Out:
# Inputs(X): 45.2 mm rain, 100 bags.
# Output(y): 3200 LRD.

# %% [markdown]
# Understanding print Statement

# %%
Liberia= 1847
print(Liberia)
print("Liberia")
# Out:
# 1847
# Liberia

# %% [markdown]
# Understanding Variables

# %%
plum=50
print("plum previous price was:",plum)
plum=80
print("plum new price is:",plum)
# Out:
# plum previous price was: 50
# plum new price is: 80

# %% [markdown]
# DATA TYPES

# %%
quantity = 50
price = 150.50
item_name = "tomatoes"
stall_is_open = True

print(type(quantity)) #
print(type(price)) #
print(type(item_name)) #
print(type(stall_is_open)) #
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# TYPES CONVERSION

# %%
raw_input ="150"
price=int(raw_input) # turns string into integer
print(price+ 50) # 200

total_cost=304.5
message="your total is LRD"+ str(total_cost)
print(message)
# Out:
# 200
# your total is LRD304.5

# %% [markdown]
# Lists

# %%
goods=["tomatoes", "pepper","onions","rice"]
print(goods) # ["tomatoes", "pepper","onions","rice"]
print(goods[0]) # tomatoes
print(goods[2]) # onions
# Out:
# ['tomatoes', 'pepper', 'onions', 'rice']
# tomatoes
# onions

# %% [markdown]
# Index error

# %%
print(goods[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1599/1847229415.py in <cell line: 0>()
# ----> 1 print(goods[4])
#
# IndexError: list index out of range
