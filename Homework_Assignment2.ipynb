# %% [markdown]
# <a href="https://colab.research.google.com/github/Roseline00/Machine-Learning-with-Python-/blob/main/Homework_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Type Conversion(The Nimba Truck Report)

# %%
transport_cost = "750"

transport_cost = int(transport_cost)

total_delivery_cost = transport_cost + 250
print(f"ma christiana,your final shipping cost is:{total_delivery_cost} LRD.")
# Out:
# ma christiana,your final shipping cost is:1000 LRD.

# %% [markdown]
# Question 2: Lists & Matrices (Packing the Shipping Crate)

# %%
loose_stock = [[45],[12], [88]]

# %% [markdown]
# Question 3: Dictionaries (Tuning the Motorbike Engine)
# A. Create Dictionary

# %%
yield_model_configs = {
    "engine_type": "Decision Tree",
    "max_depth_layers": 15,
    "strict_mode": True
}
print(f"System Check: Tuning engine depth to {yield_model_configs['max_depth_layers']} branches.")
# Out:
# System Check: Tuning engine depth to 15 branches.

# %% [markdown]
# Question 4: Methods vs Attributes (The Commercial Transport Truck)

# %%
import pandas as pd

gobachop_data = pd.DataFrame({
    "Vendor": ["Ma Musu", "Sia", "Flomo"],
    "Sales": [4000, 9500, 1500]
})

print("This is the number of rows and the colums:",gobachop_data.shape)
print("\n")
print("This is the first row in the table :", "\n",gobachop_data.head(1))
print("\n")
print("This is the last row in the table:", "\n", gobachop_data.tail(1))
print("\n")
print("This is the top two row in the table:", "\n", gobachop_data.head(2))
# Out:
# This is the number of rows and the colums: (3, 2)
#
#
# This is the first row in the table :
#      Vendor  Sales
# 0  Ma Musu   4000
#
#
# This is the last row in the table:
#    Vendor  Sales
# 2  Flomo   1500
#
#
# This is the top two row in the table:
#      Vendor  Sales
# 0  Ma Musu   4000
# 1      Sia   9500
